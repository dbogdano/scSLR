# %%
# !date
# Out:
# Thu 22 Dec 2022 05:35:37 PM PST

# %%
# !echo $CONDA_PREFIX
# Out:
# /home/derek/miniconda3/envs/squint_dev

# %%
import pandas as pd
import scanpy as sc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scquint.data import load_adata_from_starsolo, add_gene_annotation, group_introns

# %%
adata_SLR = sc.read_h5ad('scQuint.h5ad')

# %%
adata_SS2 = sc.read_h5ad('scQuint_SS2.h5ad')

# %%
# Here's a scatter plot of mean PSI where each point corresponds to an intron,cell_type pair, and the x-axis could be mean PSI in 
# SMARTseq and y-axis in SLR. The introns are those appear in both SMARTseq and SLR data. To make sure the mean of PSI are representative, we only
# plot the introns with PSI is defined in more than n=10 cells of thecell cluster. The Pearson correlation here is 0.926. This shows that for matched introns in both datasets, 
# mean PSIs of intron in each cell type cluster in one dataset are al so highly correlated with another.

# %%
adata_SLR
# Out:
# AnnData object with n_obs × n_vars = 74327 × 10900
#     obs: 'batch', 'scANVI_simple'
#     var: 'chromosome', 'start', 'end', 'strand', 'intron_motif', 'annotated-0', 'total_unique_mapping-0', 'total_multi_mapping-0', 'max_overhang-0', 'annotated-1', 'total_unique_mapping-1', 'total_multi_mapping-1', 'max_overhang-1', 'annotated-2', 'total_unique_mapping-2', 'total_multi_mapping-2', 'max_overhang-2', 'annotated-3', 'total_unique_mapping-3', 'total_multi_mapping-3', 'max_overhang-3', 'annotated-4', 'total_unique_mapping-4', 'total_multi_mapping-4', 'max_overhang-4', 'annotated-5', 'total_unique_mapping-5', 'total_multi_mapping-5', 'max_overhang-5', 'gene_id_start', 'gene_id_end', 'n_genes', 'gene_id', 'gene_name', 'intron_group', 'intron_group_size', 'n_genes_per_intron_group'
#     layers: 'PSI_raw'

# %%
marker_genes = adata_SLR.var.index.intersection(adata_SS2.var.index).tolist()

genedf_SLR = sc.get.obs_df(
        adata_SLR,
        keys=["scANVI_simple", *marker_genes],
    layer='PSI_raw'
)

# %%
df_SLR=pd.Series()

for celltype in genedf_SLR.scANVI_simple.unique():
    
    genedf_SLR_ = genedf_SLR[genedf_SLR.scANVI_simple == celltype]
    
    genedf_SLR_.dropna(thresh = 10,
                 axis=1,inplace=True)

    means = genedf_SLR_.mean(axis=0)
    
   # means.name = celltype
    means.index = means.index.astype(str) + '_' + celltype
    
    df_SLR = df_SLR.append(means,
                  # ignore_index=True
                  )
# Out:
# /tmp/ipykernel_2956972/2607820263.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_SLR=pd.Series()
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,
# /tmp/ipykernel_2956972/2607820263.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SLR_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/2607820263.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SLR_.mean(axis=0)
# /tmp/ipykernel_2956972/2607820263.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SLR = df_SLR.append(means,

# %%
marker_genes = adata_SLR.var.index.intersection(adata_SS2.var.index).tolist()

genedf_SS2 = sc.get.obs_df(
        adata_SS2,
        keys=["C_scANVI_simple", *marker_genes],
    layer='PSI_raw'
)

# %%
df_SS2=pd.Series()

for celltype in genedf_SS2.C_scANVI_simple.unique():
    
    genedf_SS2_ = genedf_SS2[genedf_SS2.C_scANVI_simple == celltype]
    
    genedf_SS2_.dropna(thresh = 10,
                 axis=1,inplace=True)

    means = genedf_SS2_.mean(axis=0)
    
    #means.name = celltype
    means.index = means.index.astype(str) + '_' + celltype
    
    df_SS2 = df_SS2.append(means,
                  # ignore_index=True
                  )
# Out:
# /tmp/ipykernel_2956972/1864385555.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_SS2=pd.Series()
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,
# /tmp/ipykernel_2956972/1864385555.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_SS2_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1864385555.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = genedf_SS2_.mean(axis=0)
# /tmp/ipykernel_2956972/1864385555.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_SS2 = df_SS2.append(means,

# %%
df_SS2 = df_SS2[df_SS2.index.isin(df_SLR.index)]

# %%
df_SLR = df_SLR[df_SLR.index.isin(df_SS2.index)]

# %%
df_SLR.corr(df_SS2,method = 'pearson')
# Out:
# 0.9509359361344696

# %%
df_SS2
# Out:
# NOC2L_chr1:944801-945041_nEN          0.318182
# NOC2L_chr1:944801-945056_nEN          0.681818
# CDK11B_chr1:1649638-1652438_nEN       0.947368
# CDK11B_chr1:1649638-1652468_nEN       0.052632
# CDK11A_chr1:1716479-1719327_nEN       0.187500
#                                         ...
# SSR4_chrX:153797533-153797724_RBC     0.998466
# RPL10_chrX:154398395-154398496_RBC    0.994523
# RPL10_chrX:154398399-154398496_RBC    0.005477
# RPL10_chrX:154399942-154400701_RBC    0.028696
# RPL10_chrX:154400627-154400701_RBC    0.971304
# Length: 95774, dtype: float64

# %%
df_SLR
# Out:
# CDK11B_chr1:1649638-1652438_IPC-nEN     0.921053
# CDK11B_chr1:1649638-1652468_IPC-nEN     0.078947
# GNB1_chr1:1787054-1787321_IPC-nEN       0.950413
# GNB1_chr1:1787054-1787325_IPC-nEN       0.049587
# RPL22_chr1:6186817-6192929_IPC-nEN      0.956434
#                                           ...
# SSR4_chrX:153797533-153797724_Mural     1.000000
# RPL10_chrX:154398395-154398496_Mural    0.976667
# RPL10_chrX:154398399-154398496_Mural    0.023333
# RPL10_chrX:154399942-154400701_Mural    0.040622
# RPL10_chrX:154400627-154400701_Mural    0.959378
# Length: 95774, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(6, 6))

sns.scatterplot(x=df_SS2,
                y=df_SLR,
                s=2,
                linewidth=0,
                ax=ax
                
               )

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

ax.set_title('r = 0.950',loc='left')

ax.set_xlabel('Ψ SMART-seq II', fontsize=16)
ax.set_ylabel('Ψ scSLR-seq', fontsize=16)



# sns.kdeplot(
#     data=tips,
#     x=df_SS2,
#     y=df,
#     levels=10,
#     fill=True,
#     alpha=1,#0.6,
#     cut=0,
#     ax=ax,
#    # clip
# )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 11
#       1 fig, ax = plt.subplots(figsize=(6, 6))
#       3 sns.scatterplot(x=df_SS2,
#       4                 y=df_SLR,
#       5                 s=2,
#    (...)
#       8
#       9                )
# ---> 11 ax.spines.right.set_visible(False)
#      12 ax.spines.top.set_visible(False)
#      14 ax.set_title('r = 0.950',loc='left')
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'right'

# %%
data = pd.concat([df_SS2,df_SLR],axis=1)

# %%
data.columns = ['SS2','SLR']

# %%
fig, ax = plt.subplots(figsize=(6, 6))

sns.regplot(data = data,
            x='SS2',
            y='SLR',
            scatter_kws={'s':2, 'linewidth':0},
            line_kws={"lw":5, 'color':'black'},
            ax=ax
                
               )

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

ax.set_title('r = 0.950',loc='left')

ax.set_ylabel('Ψ SMART-seq II', fontsize=16)
ax.set_xlabel('Ψ scSLR-seq', fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 12
#       1 fig, ax = plt.subplots(figsize=(6, 6))
#       3 sns.regplot(data = data,
#       4             x='SS2',
#       5             y='SLR',
#    (...)
#       9
#      10                )
# ---> 12 plt.spines.right.set_visible(False)
#      13 ax.spines.top.set_visible(False)
#      15 ax.set_title('r = 0.950',loc='left')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'spines'

# %%
from scipy import stats

# %%
values = np.vstack([df_SLR, df_SS2])

# %%
values
# Out:
# array([[0.92105263, 0.07894737, 0.95041322, ..., 0.02333333, 0.04062233,
#         0.95937767],
#        [0.31818182, 0.68181818, 0.94736842, ..., 0.00547748, 0.02869644,
#         0.97130356]])

# %%
kernel = stats.gaussian_kde(values)(values)

# %%
idx = kernel.argsort()
x, y, z = df_SLR[idx], df_SS2[idx], kernel[idx]

# %%
fig, ax = plt.subplots(figsize=(6, 6))

sns.scatterplot(
    x=x,
    y=y,
    c=z,
    s=6,
    cmap="plasma",
    ax=ax,
    linewidth=0,
    alpha=.6
)

# ax.spines.right.set_visible(False)
# ax.spines.top.set_visible(False)

# ax.spines.bottom.set_linewidth(2)
# ax.spines.left.set_linewidth(2)


ax.set_title('r = 0.950',loc='left')

ax.set_ylabel('Ψ SMART-seq II', fontsize=16)
ax.set_xlabel('Ψ scSLR-seq', fontsize=16)
# Out:
# Text(0.5, 0, 'Ψ scSLR-seq')

# %%
df_SLR
# Out:
# CDK11B_chr1:1649638-1652438_IPC-nEN     0.921053
# CDK11B_chr1:1649638-1652468_IPC-nEN     0.078947
# GNB1_chr1:1787054-1787321_IPC-nEN       0.950413
# GNB1_chr1:1787054-1787325_IPC-nEN       0.049587
# RPL22_chr1:6186817-6192929_IPC-nEN      0.956434
#                                           ...
# SSR4_chrX:153797533-153797724_Mural     1.000000
# RPL10_chrX:154398395-154398496_Mural    0.976667
# RPL10_chrX:154398399-154398496_Mural    0.023333
# RPL10_chrX:154399942-154400701_Mural    0.040622
# RPL10_chrX:154400627-154400701_Mural    0.959378
# Length: 95774, dtype: float64

# %%
df_SLR
# Out:
# CDK11B_chr1:1649638-1652438_IPC-nEN     0.921053
# CDK11B_chr1:1649638-1652468_IPC-nEN     0.078947
# GNB1_chr1:1787054-1787321_IPC-nEN       0.950413
# GNB1_chr1:1787054-1787325_IPC-nEN       0.049587
# RPL22_chr1:6186817-6192929_IPC-nEN      0.956434
#                                           ...
# SSR4_chrX:153797533-153797724_Mural     1.000000
# RPL10_chrX:154398395-154398496_Mural    0.976667
# RPL10_chrX:154398399-154398496_Mural    0.023333
# RPL10_chrX:154399942-154400701_Mural    0.040622
# RPL10_chrX:154400627-154400701_Mural    0.959378
# Length: 95774, dtype: float64

# %%
unique(marker_genes[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 unique(marker_genes[:10])
#
# NameError: name 'unique' is not defined

# %%
marker_genes_genes = list(set([i.split('_')[0] for i in marker_genes]))

# %%
adata_gene = sc.read_h5ad('/home/derek/analysis_8/SLR/prental_brain/scANVI_label.h5ad')

# %%
genedf_gene = sc.get.obs_df(
        adata_gene,
        keys=["C_scANVI_simple", *marker_genes_genes],
   # layer='PSI_raw'
)

# %%
df_gene=pd.Series()

for celltype in adata_gene.obs.C_scANVI_simple.unique():
    
    genedf_gene_ = genedf_gene[genedf_gene.C_scANVI_simple == celltype]
    
    genedf_gene_.dropna(thresh = 10,
                 axis=1,inplace=True)

    means_gene = genedf_gene_.mean(axis=0)
    
   # means.name = celltype
    means_gene.index = means_gene.index.astype(str) + '_' + celltype
    
    df_gene = df_gene.append(means,
                  # ignore_index=True
                  )
# Out:
# /tmp/ipykernel_2956972/1463165050.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_gene=pd.Series()
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,
# /tmp/ipykernel_2956972/1463165050.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genedf_gene_.dropna(thresh = 10,
# /tmp/ipykernel_2956972/1463165050.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means_gene = genedf_gene_.mean(axis=0)
# /tmp/ipykernel_2956972/1463165050.py:15: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_gene = df_gene.append(means,

# %%
df_gene
# Out:
# GNB1_chr1:1787054-1787321_U3         0.805102
# GNB1_chr1:1787054-1787325_U3         0.194898
# PARK7_chr1:7961736-7962762_U3        0.233333
# PARK7_chr1:7961794-7962762_U3        0.766667
# PARK7_chr1:7962876-7969344_U3        0.000000
#                                        ...
# HMGB3_chrX:150983592-150985594_U3    0.000000
# RPL10_chrX:154398395-154398496_U3    1.000000
# RPL10_chrX:154398399-154398496_U3    0.000000
# RPL10_chrX:154399942-154400701_U3    0.071041
# RPL10_chrX:154400627-154400701_U3    0.928959
# Length: 27090, dtype: float64
