# %% [markdown]
# ## scQuint Data Preprocessing

# %%
##processing pipeline of cellxSJ matric StarSolo output for use with scQuint. Scripts by Gonzalo Benegas

# %%
# !date
# Out:
# Sat Jan 28 12:18:03 PST 2023

# %%
# !echo $CONDA_PREFIX
# Out:
# /c4/home/derek/miniconda3/envs/scquint_3

# %%
import anndata
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scanpy as sc
import seaborn as sns
from umap import UMAP

from scquint.data import add_gene_annotation, group_introns, load_adata_from_starsolo, filter_singletons

# %%
output_dir='/c4/home/derek/data1/derek/data_scSLR/prenatal_brain/'

# %% [markdown]
# ### Load Gene Expression Anndata

# %%
# we will extract obs and X_umap
adata_exp = anndata.read_h5ad(output_dir+"scANVI_label.h5ad")
adata_exp
# Out:
# AnnData object with n_obs × n_vars = 74327 × 36385
#     obs: 'n_counts', 'batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_mito', '_scvi_batch', '_scvi_labels', 'leiden', 'scANVI_simple', 'tech', 'C_scANVI', 'C_scANVI_simple'
#     var: 'mito', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'C_scANVI_simple_colors', '_scvi_manager_uuid', '_scvi_uuid', 'batch_colors', 'hvg', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata_exp.obs
# Out:
#                     n_counts batch  n_genes_by_counts  \
# AAACCCAAGAACCGCA-0    5027.0     0               2618
# AAACCCAAGCAACAGC-0    6498.0     0               2982
# AAACCCAAGCCTGGAA-0    4639.0     0               2487
# AAACCCACAAACCACT-0    1972.0     0               1319
# AAACCCACACCAGCCA-0    6391.0     0               3199
# ...                      ...   ...                ...
# TTTGTTGTCCGTAGTA-5    2241.0     5               1434
# TTTGTTGTCCTGTTGC-5    6845.0     5               2967
# TTTGTTGTCTCAAAGC-5    5440.0     5               2678
# TTTGTTGTCTGTAAGC-5    9132.0     5               3735
# TTTGTTGTCTTACCAT-5   18376.0     5               5581
#
#                     log1p_n_genes_by_counts  total_counts  log1p_total_counts  \
# AAACCCAAGAACCGCA-0                 7.870548        5027.0            8.522778
# AAACCCAAGCAACAGC-0                 8.000685        6498.0            8.779404
# AAACCCAAGCCTGGAA-0                 7.819234        4639.0            8.442470
# AAACCCACAAACCACT-0                 7.185387        1972.0            7.587310
# AAACCCACACCAGCCA-0                 8.070906        6391.0            8.762802
# ...                                     ...           ...                 ...
# TTTGTTGTCCGTAGTA-5                 7.268920        2241.0            7.715124
# TTTGTTGTCCTGTTGC-5                 7.995644        6845.0            8.831420
# TTTGTTGTCTCAAAGC-5                 7.893199        5440.0            8.601718
# TTTGTTGTCTGTAAGC-5                 8.225771        9132.0            9.119650
# TTTGTTGTCTTACCAT-5                 8.627302       18376.0            9.818855
#
#                     pct_counts_mito  _scvi_batch  _scvi_labels leiden  \
# AAACCCAAGAACCGCA-0         4.356475            0             0      0
# AAACCCAAGCAACAGC-0         3.985842            0             0     16
# AAACCCAAGCCTGGAA-0         1.832291            0             0      5
# AAACCCACAAACCACT-0         1.926978            0             0      0
# AAACCCACACCAGCCA-0         5.711156            0             0     13
# ...                             ...          ...           ...    ...
# TTTGTTGTCCGTAGTA-5         2.052655            5             0      5
# TTTGTTGTCCTGTTGC-5         7.363039            5             0      3
# TTTGTTGTCTCAAAGC-5         2.702206            5             0      3
# TTTGTTGTCTGTAAGC-5         5.256242            5             0     14
# TTTGTTGTCTTACCAT-5         2.198520            5             0     21
#
#                    scANVI_simple tech     C_scANVI C_scANVI_simple
# AAACCCAAGAACCGCA-0       IPC-nEN  SLR     IPC-nEN2         IPC-nEN
# AAACCCAAGCAACAGC-0         EN-V1  SLR      EN-PFC2          EN-PFC
# AAACCCAAGCCTGGAA-0    IN-CTX-MGE  SLR  IN-CTX-MGE2      IN-CTX-MGE
# AAACCCACAAACCACT-0           nEN  SLR     nEN-late             nEN
# AAACCCACACCAGCCA-0       IPC-div  SLR     IPC-div2         IPC-div
# ...                          ...  ...          ...             ...
# TTTGTTGTCCGTAGTA-5    IN-CTX-MGE  SLR  IN-CTX-MGE1      IN-CTX-MGE
# TTTGTTGTCCTGTTGC-5         EN-V1  SLR      EN-V1-3           EN-V1
# TTTGTTGTCTCAAAGC-5         EN-V1  SLR      EN-V1-3           EN-V1
# TTTGTTGTCTGTAAGC-5         EN-V1  SLR      EN-V1-3           EN-V1
# TTTGTTGTCTTACCAT-5           OPC  SLR          OPC             OPC
#
# [74327 rows x 14 columns]

# %%
sc.pl.umap(adata_exp,
           color=['C_scANVI_simple']
          )
# Out:
# /c4/home/derek/miniconda3/envs/scquint_3/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### Load Splice Junction Matricies into scQuint

# %%
input_dir = "/nowakowskilab/data1/derek/data_scSLR/prenatal_brain/STAR_outs/"

# %%
# %%time
adatas_spl = {}
samples = ["GW16_1", "GW16_2", "GW17_1", "GW21_1", "GW21_2", "GW23_1"]
for sample in samples:
    print(sample)
    try:
        adata_spl_sample = load_adata_from_starsolo(input_dir+f"/{sample}/StarOut/Solo.out/SJ/raw/", var_filename="SJ.out.tab")
    except:
        adata_spl_sample = load_adata_from_starsolo(input_dir+f"/{sample}/StarOut/Solo.out/SJ/raw/", var_filename="SJ.out.tab")
    adatas_spl[sample] = adata_spl_sample
# Out:
# GW16_1
# Filtering out undefined strand.
# GW16_2
# Filtering out undefined strand.
# GW17_1
# Filtering out undefined strand.
# GW21_1
# Filtering out undefined strand.
# GW21_2
# Filtering out undefined strand.
# GW23_1
# Filtering out undefined strand.
# CPU times: user 16min 33s, sys: 50.3 s, total: 17min 23s
# Wall time: 17min 23s

# %%
adata_spl = anndata.concat(adatas_spl, index_unique="-", merge="same")
adata_spl
# Out:
# AnnData object with n_obs × n_vars = 40769280 × 254570
#     var: 'chromosome', 'start', 'end', 'strand', 'intron_motif'

# %%
adata_spl.var
# Out:
#                         chromosome  start     end strand  intron_motif
# chr1:14830-14929              chr1  14830   14929      -             2
# chr1:14830-14969              chr1  14830   14969      -             2
# chr1:14830-15020              chr1  14830   15020      -             2
# chr1:14830-15795              chr1  14830   15795      -             2
# chr1:14830-186316             chr1  14830  186316      -             2
# ...                            ...    ...     ...    ...           ...
# KI270720.1:22815-26115  KI270720.1  22815   26115      -             2
# KI270718.1:15053-15339  KI270718.1  15053   15339      -             2
# KI270718.1:23587-26789  KI270718.1  23587   26789      +             1
# KI270718.1:26028-26789  KI270718.1  26028   26789      +             1
# KI270303.1:1376-1715    KI270303.1   1376    1715      +             1
#
# [254570 rows x 5 columns]

# %%
##fix obs names
adata_spl.obs_names = adata_spl.obs_names.str.replace(
    'GW16_1','0').str.replace(
    'GW16_2','1').str.replace(
    'GW17_1','2').str.replace(
    'GW21_1','3').str.replace(
    'GW21_2','4').str.replace(
    'GW23_1','5')

# %%
adata_spl = adata_spl[adata_exp.obs.index.values]
adata_spl.obs = adata_exp.obs
adata_spl.obsm["X_umap"] = adata_exp.obsm["X_umap"]

# %%
sc.pp.filter_genes(adata_spl, min_cells=100)
chromosomes = [f"chr{i}" for i in range(1, 23)] + ["chrX", "chrY"]
adata_spl = adata_spl[:, adata_spl.var.chromosome.isin(chromosomes)]

# %%
adata_spl.var
# Out:
#                        chromosome     start       end strand  intron_motif  \
# chr1:28326-198844            chr1     28326    198844      +             1
# chr1:827776-829002           chr1    827776    829002      +             1
# chr1:852111-852670           chr1    852111    852670      +             1
# chr1:944801-945056           chr1    944801    945056      -             2
# chr1:945147-945517           chr1    945147    945517      -             2
# ...                           ...       ...       ...    ...           ...
# chrY:20579692-20582589       chrY  20579692  20582589      +             1
# chrY:20582694-20584473       chrY  20582694  20584473      +             1
# chrY:20584525-20588023       chrY  20584525  20588023      +             1
# chrY:20588106-20589483       chrY  20588106  20589483      +             1
# chrY:20589576-20592340       chrY  20589576  20592340      +             1
#
#                         n_cells
# chr1:28326-198844           161
# chr1:827776-829002          182
# chr1:852111-852670          114
# chr1:944801-945056          244
# chr1:945147-945517          244
# ...                         ...
# chrY:20579692-20582589     1005
# chrY:20582694-20584473      838
# chrY:20584525-20588023      832
# chrY:20588106-20589483      964
# chrY:20589576-20592340     1053
#
# [81507 rows x 6 columns]

# %%
# %%time
##add annotations

gtf_path = '/c4/home/derek/data1/HDD-2/derek/reference/human_hp3_reference/genes/genes.gtf'
filter_unique_gene=True
    
gtf = pd.read_csv(
    gtf_path,
    sep="\t",
    header=None,
    comment="#",
    names=[
        "chromosome",
        "source",
        "feature",
        "start",
        "end",
        "score",
        "strand",
        "frame",
        "attribute",
    ],
)

gtf = gtf[gtf.feature == "exon"]
gtf["gene_id"] = gtf.attribute.str.extract(r'gene_id "([^;]*)";')
gtf["gene_name"] = gtf.attribute.str.extract(r'gene_name "([^;]*)";')
#gtf.chromosome = "chr" + gtf.chromosome.astype(str)

gene_id_name = gtf[["gene_id", "gene_name"]].drop_duplicates()

exon_starts = (
    gtf[["chromosome", "start", "gene_id"]].copy().rename(columns={"start": "pos"})
)
exon_starts.pos -= 1
exon_ends = (
    gtf[["chromosome", "end", "gene_id"]].copy().rename(columns={"end": "pos"})
)
exon_ends.pos += 1
exon_boundaries = pd.concat(
    [exon_starts, exon_ends], ignore_index=True
).drop_duplicates()

genes_by_exon_boundary = exon_boundaries.groupby(
    ["chromosome", "pos"]
).gene_id.unique()

adata_spl.var = (
    adata_spl.var.merge(
        genes_by_exon_boundary,
        how="left",
        left_on=["chromosome", "start"],
        right_on=["chromosome", "pos"],
    )
    .rename(columns={"gene_id": "gene_id_start"})
    .set_index(adata_spl.var.index)
)
adata_spl.var = (
    adata_spl.var.merge(
        genes_by_exon_boundary,
        how="left",
        left_on=["chromosome", "end"],
        right_on=["chromosome", "pos"],
    )
    .rename(columns={"gene_id": "gene_id_end"})
    .set_index(adata_spl.var.index)
)

def fill_na_with_empty_array(val):
    return val if isinstance(val, np.ndarray) else np.array([])

adata_spl.var.gene_id_start = adata_spl.var.gene_id_start.apply(fill_na_with_empty_array)
adata_spl.var.gene_id_end = adata_spl.var.gene_id_end.apply(fill_na_with_empty_array)

adata_spl.var["gene_id_list"] = adata_spl.var.apply(
    lambda row: np.unique(np.concatenate([row.gene_id_start, row.gene_id_end])),
    axis=1,
)
adata_spl.var["n_genes"] = adata_spl.var.gene_id_list.apply(len)
adata_spl.var.gene_id_list = adata_spl.var.gene_id_list.apply(
    lambda x: ",".join(x.tolist())
)
adata_spl.var.gene_id_start = adata_spl.var.gene_id_start.apply(
    lambda x: ",".join(x.tolist())
)
adata_spl.var.gene_id_end = adata_spl.var.gene_id_end.apply(
    lambda x: ",".join(x.tolist())
)

if filter_unique_gene:
    print("Filtering to introns associated to 1 and only 1 gene.")
    adata_spl = adata_spl[:, adata_spl.var.n_genes == 1]
    adata_spl.var["gene_id"] = adata_spl.var.gene_id_list
    adata_spl.var.drop(columns=["gene_id_list",], inplace=True)
    adata_spl.var = adata_spl.var.merge(gene_id_name, how="left", on="gene_id").set_index(
        adata_spl.var.index
    )
    adata_spl.var.index = adata_spl.var.gene_name.astype(str) + "_" + adata_spl.var.index.astype(str)
# Out:
# Filtering to introns associated to 1 and only 1 gene.
# <timed exec>:92: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
# CPU times: user 3min 35s, sys: 23.4 s, total: 3min 59s
# Wall time: 3min 49s

# %%
def overlaps(A,B):
    '''
    Checks if A and B overlaps
    '''

    if A[1] < B[0] or B[1] < A[0]:
        return False
    else: return True

# %%
def cluster_intervals(E):
    ''' Clusters intervals together. '''
    E.sort()
    if len(E) == 0:
        return [], []
    current = E[0]
    Eclusters, cluster = [], []

    i = 0
    while i < len(E):

        if overlaps(E[i], current):
            cluster.append(E[i])
        else:
            Eclusters.append(cluster)
            cluster = [E[i]]
        current = (E[i][0], max([current[1], E[i][1]]))
        i += 1

    if len(cluster) > 0:
        
        Eclusters.append(cluster)

    
    return Eclusters, E

# %%
adata_spl.var.head()
# Out:
#                              chromosome   start     end strand  intron_motif  \
# LINC01128_chr1:827776-829002       chr1  827776  829002      +             1
# LINC01128_chr1:852111-852670       chr1  852111  852670      +             1
# NOC2L_chr1:944801-945056           chr1  944801  945056      -             2
# NOC2L_chr1:945147-945517           chr1  945147  945517      -             2
# NOC2L_chr1:945654-946172           chr1  945654  946172      -             2
#
#                               n_cells    gene_id_start      gene_id_end  \
# LINC01128_chr1:827776-829002      182  ENSG00000228794  ENSG00000228794
# LINC01128_chr1:852111-852670      114  ENSG00000228794  ENSG00000228794
# NOC2L_chr1:944801-945056          244  ENSG00000188976  ENSG00000188976
# NOC2L_chr1:945147-945517          244  ENSG00000188976  ENSG00000188976
# NOC2L_chr1:945654-946172          221  ENSG00000188976  ENSG00000188976
#
#                               n_genes          gene_id  gene_name
# LINC01128_chr1:827776-829002        1  ENSG00000228794  LINC01128
# LINC01128_chr1:852111-852670        1  ENSG00000228794  LINC01128
# NOC2L_chr1:944801-945056            1  ENSG00000188976      NOC2L
# NOC2L_chr1:945147-945517            1  ENSG00000188976      NOC2L
# NOC2L_chr1:945654-946172            1  ENSG00000188976      NOC2L

# %%
# for libl in flist:
        
#         lib = libl.strip()
#         if not os.path.isfile(lib):
#             continue

#         if options.verbose:
#             sys.stderr.write("scanning %s...\n"%lib)

#         if lib[-3:] == ".gz": F = gzip.open(lib)
#         else: F = open(lib)
by_chrom = {}

for index, row in adata_spl.var.iterrows():

    chrom = row['chromosome']
    A = row['start']
    B = row['end']
    counts = row['n_cells']
    strand = row['strand']
    
    A, B = int(A), int(B)
    if B-A > int(500000): continue
    try: by_chrom[(chrom,strand)][(A,B)] = int(counts) + by_chrom[(chrom, strand)][(A,B)]
    except: 
        try: by_chrom[(chrom,strand)][(A,B)] = int(counts)
        except: by_chrom[(chrom, strand)] = {(A,B):int(counts)}

# %%
fout = open('leafcutter_clusters.txt', 'w')
Ncluster = 0

temp = pd.DataFrame()

for chrom in by_chrom:
    read_ks = [k for k,v in by_chrom[chrom].items() if v >= 3] # a junction must have at least 3 reads
    read_ks.sort()

    clu = cluster_intervals(read_ks)[0]
    for cl in clu:
        if len(cl) > 1: # if cluster has more than one intron  
            buf = '%s:%s '%chrom
            for interval, count in [(x, by_chrom[chrom][x]) for x in cl]:
                {buf:interval}"
            #fout.write(buf+'\n')
        Ncluster += 1
fout.close()

# %%
# pd.read_csv('leafcutter_clusters.txt',sep=" ")

# %%
def group_introns(adata, by="three_prime", filter_unique_gene_per_group=True):
    if by == "three_prime":
        adata.var["intron_group"] = adata.var.apply(
            lambda intron: intron.chromosome
            + "_"
            + (str(intron.end) if intron.strand == "+" else str(intron.start))
            + "_"
            + intron.strand,
            axis=1,
        )
    elif by == "five_prime":
        adata.var["intron_group"] = adata.var.apply(
            lambda intron: intron.chromosome
            + "_"
            + (str(intron.start) if intron.strand == "+" else str(intron.end))
            + "_"
            + intron.strand,
            axis=1,
        )
    elif by == "gene":
        adata.var["intron_group"] = adata.var.gene_id
    else:
        raise Exception(f"Grouping by {by} not yet supported.")

    intron_group_sizes = (
        adata.var.intron_group.value_counts()
        .to_frame()
        .rename(columns={"intron_group": "intron_group_size"})
    )
    adata.var = adata.var.merge(
        intron_group_sizes, how="left", left_on="intron_group", right_index=True
    ).set_index(adata.var.index)
    print("Filtering singletons.")
    adata = adata[:, adata.var.intron_group_size > 1]


    if filter_unique_gene_per_group:
        print("Filtering intron groups associated with more than 1 gene.")
        n_genes_per_intron_group = adata.var.groupby("intron_group").gene_id.nunique().to_frame().rename(columns={"gene_id": "n_genes_per_intron_group"})
        adata.var = adata.var.merge(n_genes_per_intron_group, how="left", left_on="intron_group", right_index=True)
        adata = adata[:, adata.var.n_genes_per_intron_group==1]
        adata.var.intron_group = adata.var.gene_name.astype(str) + "_" + adata.var.intron_group.astype(str)

    return adata

# %%
def group_introns(adata, by="three_prime", filter_unique_gene_per_group=True):
    if by == "three_prime":
        adata.var["intron_group"] = adata.var.apply(
            lambda intron: intron.chromosome
            + "_"
            + (str(intron.end) if intron.strand == "+" else str(intron.start))
            + "_"
            + intron.strand,
            axis=1,
        )
    elif by == "five_prime":
        adata.var["intron_group"] = adata.var.apply(
            lambda intron: intron.chromosome
            + "_"
            + (str(intron.start) if intron.strand == "+" else str(intron.end))
            + "_"
            + intron.strand,
            axis=1,
        )
    elif by == "gene":
        adata.var["intron_group"] = adata.var.gene_id
    else:
        raise Exception(f"Grouping by {by} not yet supported.")

    intron_group_sizes = (
        adata.var.intron_group.value_counts()
        .to_frame()
        .rename(columns={"intron_group": "intron_group_size"})
    )
    adata.var = adata.var.merge(
        intron_group_sizes, how="left", left_on="intron_group", right_index=True
    ).set_index(adata.var.index)
    print("Filtering singletons.")
    adata = adata[:, adata.var.intron_group_size > 1]


    if filter_unique_gene_per_group:
        print("Filtering intron groups associated with more than 1 gene.")
        n_genes_per_intron_group = adata.var.groupby("intron_group").gene_id.nunique().to_frame().rename(columns={"gene_id": "n_genes_per_intron_group"})
        adata.var = adata.var.merge(n_genes_per_intron_group, how="left", left_on="intron_group", right_index=True)
        adata = adata[:, adata.var.n_genes_per_intron_group==1]
        adata.var.intron_group = adata.var.gene_name.astype(str) + "_" + adata.var.intron_group.astype(str)

    return adata

# %%
adata_spl.var
# Out:
#                               chromosome     start       end strand  \
# LINC01128_chr1:827776-829002        chr1    827776    829002      +
# LINC01128_chr1:852111-852670        chr1    852111    852670      +
# NOC2L_chr1:944801-945056            chr1    944801    945056      -
# NOC2L_chr1:945147-945517            chr1    945147    945517      -
# NOC2L_chr1:945654-946172            chr1    945654    946172      -
# ...                                  ...       ...       ...    ...
# EIF1AY_chrY:20579692-20582589       chrY  20579692  20582589      +
# EIF1AY_chrY:20582694-20584473       chrY  20582694  20584473      +
# EIF1AY_chrY:20584525-20588023       chrY  20584525  20588023      +
# EIF1AY_chrY:20588106-20589483       chrY  20588106  20589483      +
# EIF1AY_chrY:20589576-20592340       chrY  20589576  20592340      +
#
#                                intron_motif  n_cells    gene_id_start  \
# LINC01128_chr1:827776-829002              1      182  ENSG00000228794
# LINC01128_chr1:852111-852670              1      114  ENSG00000228794
# NOC2L_chr1:944801-945056                  2      244  ENSG00000188976
# NOC2L_chr1:945147-945517                  2      244  ENSG00000188976
# NOC2L_chr1:945654-946172                  2      221  ENSG00000188976
# ...                                     ...      ...              ...
# EIF1AY_chrY:20579692-20582589             1     1005  ENSG00000198692
# EIF1AY_chrY:20582694-20584473             1      838  ENSG00000198692
# EIF1AY_chrY:20584525-20588023             1      832  ENSG00000198692
# EIF1AY_chrY:20588106-20589483             1      964  ENSG00000198692
# EIF1AY_chrY:20589576-20592340             1     1053  ENSG00000198692
#
#                                    gene_id_end  n_genes          gene_id  \
# LINC01128_chr1:827776-829002   ENSG00000228794        1  ENSG00000228794
# LINC01128_chr1:852111-852670   ENSG00000228794        1  ENSG00000228794
# NOC2L_chr1:944801-945056       ENSG00000188976        1  ENSG00000188976
# NOC2L_chr1:945147-945517       ENSG00000188976        1  ENSG00000188976
# NOC2L_chr1:945654-946172       ENSG00000188976        1  ENSG00000188976
# ...                                        ...      ...              ...
# EIF1AY_chrY:20579692-20582589  ENSG00000198692        1  ENSG00000198692
# EIF1AY_chrY:20582694-20584473  ENSG00000198692        1  ENSG00000198692
# EIF1AY_chrY:20584525-20588023  ENSG00000198692        1  ENSG00000198692
# EIF1AY_chrY:20588106-20589483  ENSG00000198692        1  ENSG00000198692
# EIF1AY_chrY:20589576-20592340  ENSG00000198692        1  ENSG00000198692
#
#                                gene_name
# LINC01128_chr1:827776-829002   LINC01128
# LINC01128_chr1:852111-852670   LINC01128
# NOC2L_chr1:944801-945056           NOC2L
# NOC2L_chr1:945147-945517           NOC2L
# NOC2L_chr1:945654-946172           NOC2L
# ...                                  ...
# EIF1AY_chrY:20579692-20582589     EIF1AY
# EIF1AY_chrY:20582694-20584473     EIF1AY
# EIF1AY_chrY:20584525-20588023     EIF1AY
# EIF1AY_chrY:20588106-20589483     EIF1AY
# EIF1AY_chrY:20589576-20592340     EIF1AY
#
# [78543 rows x 11 columns]

# %%
adata_spl_3p = group_introns(adata_spl.copy(), by="three_prime")
adata_spl_3p.var["grouping"] = "three_prime"
adata_spl_3p
# Out:
# Filtering singletons.
# Filtering intron groups associated with more than 1 gene.
# /c4/home/derek/miniconda3/envs/scquint_3/lib/python3.10/site-packages/pandas/core/generic.py:5931: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   self[name] = value
# AnnData object with n_obs × n_vars = 74327 × 7623
#     obs: 'n_counts', 'batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_mito', '_scvi_batch', '_scvi_labels', 'leiden', 'scANVI_simple', 'tech', 'C_scANVI', 'C_scANVI_simple'
#     var: 'chromosome', 'start', 'end', 'strand', 'intron_motif', 'n_cells', 'gene_id_start', 'gene_id_end', 'n_genes', 'gene_id', 'gene_name', 'intron_group', 'intron_group_size', 'n_genes_per_intron_group', 'grouping'
#     obsm: 'X_umap'

# %%
#adata_spl_3p.write_h5ad(output_dir+'spl_3prime_splice_acceptor_prenatal.h5ad')

# %%
adata_spl_5p = group_introns(adata_spl.copy(), by="five_prime")
adata_spl_5p.var["grouping"] = "five_prime"
adata_spl_5p
# Out:
# Filtering singletons.
# Filtering intron groups associated with more than 1 gene.
# /c4/home/derek/miniconda3/envs/scquint_3/lib/python3.10/site-packages/pandas/core/generic.py:5931: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   self[name] = value
# AnnData object with n_obs × n_vars = 74327 × 7184
#     obs: 'n_counts', 'batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_mito', '_scvi_batch', '_scvi_labels', 'leiden', 'scANVI_simple', 'tech', 'C_scANVI', 'C_scANVI_simple'
#     var: 'chromosome', 'start', 'end', 'strand', 'intron_motif', 'n_cells', 'gene_id_start', 'gene_id_end', 'n_genes', 'gene_id', 'gene_name', 'intron_group', 'intron_group_size', 'n_genes_per_intron_group', 'grouping'
#     obsm: 'X_umap'

# %%
temp = pd.concat([adata_spl_3p.var.copy(), adata_spl_5p.var.copy()])

# %%
temp = temp.sort_values(['chromosome','start'])

# %%
temp
# Out:
#                               chromosome     start       end strand  \
# HES4_chr1:999614-999691             chr1    999614    999691      -
# HES4_chr1:999614-999865             chr1    999614    999865      -
# HES4_chr1:999614-999865             chr1    999614    999865      -
# HES4_chr1:999788-999865             chr1    999788    999865      -
# AURKAIP1_chr1:1374791-1374996       chr1   1374791   1374996      -
# ...                                  ...       ...       ...    ...
# USP9Y_chrY:12702056-12709387        chrY  12702056  12709387      +
# USP9Y_chrY:12702056-12707759        chrY  12702056  12707759      +
# USP9Y_chrY:12702056-12708633        chrY  12702056  12708633      +
# USP9Y_chrY:12702056-12709387        chrY  12702056  12709387      +
# USP9Y_chrY:12708694-12709387        chrY  12708694  12709387      +
#
#                                intron_motif  n_cells    gene_id_start  \
# HES4_chr1:999614-999691                   2      724  ENSG00000188290
# HES4_chr1:999614-999865                   2      217  ENSG00000188290
# HES4_chr1:999614-999865                   2      217  ENSG00000188290
# HES4_chr1:999788-999865                   2      279  ENSG00000188290
# AURKAIP1_chr1:1374791-1374996             2      223  ENSG00000175756
# ...                                     ...      ...              ...
# USP9Y_chrY:12702056-12709387              1     1134  ENSG00000114374
# USP9Y_chrY:12702056-12707759              1      151  ENSG00000114374
# USP9Y_chrY:12702056-12708633              1      192  ENSG00000114374
# USP9Y_chrY:12702056-12709387              1     1134  ENSG00000114374
# USP9Y_chrY:12708694-12709387              1      243  ENSG00000114374
#
#                                    gene_id_end  n_genes          gene_id  \
# HES4_chr1:999614-999691        ENSG00000188290        1  ENSG00000188290
# HES4_chr1:999614-999865        ENSG00000188290        1  ENSG00000188290
# HES4_chr1:999614-999865        ENSG00000188290        1  ENSG00000188290
# HES4_chr1:999788-999865        ENSG00000188290        1  ENSG00000188290
# AURKAIP1_chr1:1374791-1374996  ENSG00000175756        1  ENSG00000175756
# ...                                        ...      ...              ...
# USP9Y_chrY:12702056-12709387   ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12702056-12707759   ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12702056-12708633   ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12702056-12709387   ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12708694-12709387   ENSG00000114374        1  ENSG00000114374
#
#                               gene_name             intron_group  \
# HES4_chr1:999614-999691            HES4       HES4_chr1_999614_-
# HES4_chr1:999614-999865            HES4       HES4_chr1_999614_-
# HES4_chr1:999614-999865            HES4       HES4_chr1_999865_-
# HES4_chr1:999788-999865            HES4       HES4_chr1_999865_-
# AURKAIP1_chr1:1374791-1374996  AURKAIP1  AURKAIP1_chr1_1374791_-
# ...                                 ...                      ...
# USP9Y_chrY:12702056-12709387      USP9Y    USP9Y_chrY_12709387_+
# USP9Y_chrY:12702056-12707759      USP9Y    USP9Y_chrY_12702056_+
# USP9Y_chrY:12702056-12708633      USP9Y    USP9Y_chrY_12702056_+
# USP9Y_chrY:12702056-12709387      USP9Y    USP9Y_chrY_12702056_+
# USP9Y_chrY:12708694-12709387      USP9Y    USP9Y_chrY_12709387_+
#
#                                intron_group_size  n_genes_per_intron_group  \
# HES4_chr1:999614-999691                        2                         1
# HES4_chr1:999614-999865                        2                         1
# HES4_chr1:999614-999865                        2                         1
# HES4_chr1:999788-999865                        2                         1
# AURKAIP1_chr1:1374791-1374996                  2                         1
# ...                                          ...                       ...
# USP9Y_chrY:12702056-12709387                   2                         1
# USP9Y_chrY:12702056-12707759                   3                         1
# USP9Y_chrY:12702056-12708633                   3                         1
# USP9Y_chrY:12702056-12709387                   3                         1
# USP9Y_chrY:12708694-12709387                   2                         1
#
#                                   grouping
# HES4_chr1:999614-999691        three_prime
# HES4_chr1:999614-999865        three_prime
# HES4_chr1:999614-999865         five_prime
# HES4_chr1:999788-999865         five_prime
# AURKAIP1_chr1:1374791-1374996  three_prime
# ...                                    ...
# USP9Y_chrY:12702056-12709387   three_prime
# USP9Y_chrY:12702056-12707759    five_prime
# USP9Y_chrY:12702056-12708633    five_prime
# USP9Y_chrY:12702056-12709387    five_prime
# USP9Y_chrY:12708694-12709387   three_prime
#
# [14807 rows x 15 columns]

# %%
gene_names = temp.gene_name.unique()

# %%
gene_names = gene_names[:20]

# %%
# Out:
# Index(['chromosome', 'start', 'end', 'strand', 'intron_motif', 'n_cells',
#        'gene_id_start', 'gene_id_end', 'n_genes', 'gene_id', 'gene_name'],
#       dtype='object')

# %%
dups = temp[temp.duplicated(subset=temp.columns[:11],keep=False)]

# %%
dups
# Out:
#                              chromosome     start       end strand  \
# HES4_chr1:999614-999865            chr1    999614    999865      -
# HES4_chr1:999614-999865            chr1    999614    999865      -
# GNB1_chr1:1825500-1890819          chr1   1825500   1890819      -
# GNB1_chr1:1825500-1890819          chr1   1825500   1890819      -
# FAAP20_chr1:2193911-2194687        chr1   2193911   2194687      -
# ...                                 ...       ...       ...    ...
# USP9Y_chrY:12664687-12702009       chrY  12664687  12702009      +
# USP9Y_chrY:12686607-12702009       chrY  12686607  12702009      +
# USP9Y_chrY:12686607-12702009       chrY  12686607  12702009      +
# USP9Y_chrY:12702056-12709387       chrY  12702056  12709387      +
# USP9Y_chrY:12702056-12709387       chrY  12702056  12709387      +
#
#                               intron_motif  n_cells    gene_id_start  \
# HES4_chr1:999614-999865                  2      217  ENSG00000188290
# HES4_chr1:999614-999865                  2      217  ENSG00000188290
# GNB1_chr1:1825500-1890819                2      129  ENSG00000078369
# GNB1_chr1:1825500-1890819                2      129  ENSG00000078369
# FAAP20_chr1:2193911-2194687              2      153  ENSG00000162585
# ...                                    ...      ...              ...
# USP9Y_chrY:12664687-12702009             1      209  ENSG00000114374
# USP9Y_chrY:12686607-12702009             1      977  ENSG00000114374
# USP9Y_chrY:12686607-12702009             1      977  ENSG00000114374
# USP9Y_chrY:12702056-12709387             1     1134  ENSG00000114374
# USP9Y_chrY:12702056-12709387             1     1134  ENSG00000114374
#
#                                   gene_id_end  n_genes          gene_id  \
# HES4_chr1:999614-999865       ENSG00000188290        1  ENSG00000188290
# HES4_chr1:999614-999865       ENSG00000188290        1  ENSG00000188290
# GNB1_chr1:1825500-1890819     ENSG00000078369        1  ENSG00000078369
# GNB1_chr1:1825500-1890819     ENSG00000078369        1  ENSG00000078369
# FAAP20_chr1:2193911-2194687   ENSG00000162585        1  ENSG00000162585
# ...                                       ...      ...              ...
# USP9Y_chrY:12664687-12702009  ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12686607-12702009  ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12686607-12702009  ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12702056-12709387  ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12702056-12709387  ENSG00000114374        1  ENSG00000114374
#
#                              gene_name           intron_group  \
# HES4_chr1:999614-999865           HES4     HES4_chr1_999614_-
# HES4_chr1:999614-999865           HES4     HES4_chr1_999865_-
# GNB1_chr1:1825500-1890819         GNB1    GNB1_chr1_1825500_-
# GNB1_chr1:1825500-1890819         GNB1    GNB1_chr1_1890819_-
# FAAP20_chr1:2193911-2194687     FAAP20  FAAP20_chr1_2193911_-
# ...                                ...                    ...
# USP9Y_chrY:12664687-12702009     USP9Y  USP9Y_chrY_12664687_+
# USP9Y_chrY:12686607-12702009     USP9Y  USP9Y_chrY_12702009_+
# USP9Y_chrY:12686607-12702009     USP9Y  USP9Y_chrY_12686607_+
# USP9Y_chrY:12702056-12709387     USP9Y  USP9Y_chrY_12709387_+
# USP9Y_chrY:12702056-12709387     USP9Y  USP9Y_chrY_12702056_+
#
#                               intron_group_size  n_genes_per_intron_group  \
# HES4_chr1:999614-999865                       2                         1
# HES4_chr1:999614-999865                       2                         1
# GNB1_chr1:1825500-1890819                     2                         1
# GNB1_chr1:1825500-1890819                     2                         1
# FAAP20_chr1:2193911-2194687                   2                         1
# ...                                         ...                       ...
# USP9Y_chrY:12664687-12702009                  2                         1
# USP9Y_chrY:12686607-12702009                  4                         1
# USP9Y_chrY:12686607-12702009                  3                         1
# USP9Y_chrY:12702056-12709387                  2                         1
# USP9Y_chrY:12702056-12709387                  3                         1
#
#                                  grouping
# HES4_chr1:999614-999865       three_prime
# HES4_chr1:999614-999865        five_prime
# GNB1_chr1:1825500-1890819     three_prime
# GNB1_chr1:1825500-1890819      five_prime
# FAAP20_chr1:2193911-2194687   three_prime
# ...                                   ...
# USP9Y_chrY:12664687-12702009   five_prime
# USP9Y_chrY:12686607-12702009  three_prime
# USP9Y_chrY:12686607-12702009   five_prime
# USP9Y_chrY:12702056-12709387  three_prime
# USP9Y_chrY:12702056-12709387   five_prime
#
# [5510 rows x 15 columns]

# %%
dups.grouping
# Out:
# HES4_chr1:999614-999865         three_prime
# HES4_chr1:999614-999865          five_prime
# GNB1_chr1:1825500-1890819       three_prime
# GNB1_chr1:1825500-1890819        five_prime
# FAAP20_chr1:2193911-2194687     three_prime
#                                    ...
# USP9Y_chrY:12664687-12702009     five_prime
# USP9Y_chrY:12686607-12702009    three_prime
# USP9Y_chrY:12686607-12702009     five_prime
# USP9Y_chrY:12702056-12709387    three_prime
# USP9Y_chrY:12702056-12709387     five_prime
# Name: grouping, Length: 5510, dtype: object

# %%
dups.grouping.value_counts()
# Out:
# three_prime    2755
# five_prime     2755
# Name: grouping, dtype: int64

# %%
dups_intron_group = dups.groupby(['chromosome', 'start', 'end'])['intron_group'].apply(lambda x: ','.join(x.astype(str))).reset_index()
dups_intron_group[['intron_group_1','intron_group_2']] = dups_intron_group['intron_group'].str.split(',',expand=True)

# %%
dups_intron_group
# Out:
#      chromosome      start        end  \
# 0          chr1     999614     999865
# 1          chr1    1825500    1890819
# 2          chr1    2193911    2194687
# 3          chr1    6785576    6825091
# 4          chr1    6825211    6887653
# ...         ...        ...        ...
# 2750       chrX  154399942  154400701
# 2751       chrX  154400627  154400701
# 2752       chrY   12664687   12702009
# 2753       chrY   12686607   12702009
# 2754       chrY   12702056   12709387
#
#                                        intron_group          intron_group_1  \
# 0             HES4_chr1_999614_-,HES4_chr1_999865_-      HES4_chr1_999614_-
# 1           GNB1_chr1_1825500_-,GNB1_chr1_1890819_-     GNB1_chr1_1825500_-
# 2       FAAP20_chr1_2193911_-,FAAP20_chr1_2194687_-   FAAP20_chr1_2193911_-
# 3       CAMTA1_chr1_6825091_+,CAMTA1_chr1_6785576_+   CAMTA1_chr1_6825091_+
# 4       CAMTA1_chr1_6887653_+,CAMTA1_chr1_6825211_+   CAMTA1_chr1_6887653_+
# ...                                             ...                     ...
# 2750  RPL10_chrX_154400701_+,RPL10_chrX_154399942_+  RPL10_chrX_154400701_+
# 2751  RPL10_chrX_154400701_+,RPL10_chrX_154400627_+  RPL10_chrX_154400701_+
# 2752    USP9Y_chrY_12702009_+,USP9Y_chrY_12664687_+   USP9Y_chrY_12702009_+
# 2753    USP9Y_chrY_12702009_+,USP9Y_chrY_12686607_+   USP9Y_chrY_12702009_+
# 2754    USP9Y_chrY_12709387_+,USP9Y_chrY_12702056_+   USP9Y_chrY_12709387_+
#
#               intron_group_2
# 0         HES4_chr1_999865_-
# 1        GNB1_chr1_1890819_-
# 2      FAAP20_chr1_2194687_-
# 3      CAMTA1_chr1_6785576_+
# 4      CAMTA1_chr1_6825211_+
# ...                      ...
# 2750  RPL10_chrX_154399942_+
# 2751  RPL10_chrX_154400627_+
# 2752   USP9Y_chrY_12664687_+
# 2753   USP9Y_chrY_12686607_+
# 2754   USP9Y_chrY_12702056_+
#
# [2755 rows x 6 columns]

# %%
dups_grouping = dups.groupby(['chromosome', 'start', 'end'])['grouping'].apply(lambda x: ','.join(x.astype(str))).reset_index()

dups_intron_group[['grouping_1','grouping_2']] = dups_grouping['grouping'].str.split(',',expand=True)

# %%
dups_intron_group
# Out:
#      chromosome      start        end  \
# 0          chr1     999614     999865
# 1          chr1    1825500    1890819
# 2          chr1    2193911    2194687
# 3          chr1    6785576    6825091
# 4          chr1    6825211    6887653
# ...         ...        ...        ...
# 2750       chrX  154399942  154400701
# 2751       chrX  154400627  154400701
# 2752       chrY   12664687   12702009
# 2753       chrY   12686607   12702009
# 2754       chrY   12702056   12709387
#
#                                        intron_group          intron_group_1  \
# 0             HES4_chr1_999614_-,HES4_chr1_999865_-      HES4_chr1_999614_-
# 1           GNB1_chr1_1825500_-,GNB1_chr1_1890819_-     GNB1_chr1_1825500_-
# 2       FAAP20_chr1_2193911_-,FAAP20_chr1_2194687_-   FAAP20_chr1_2193911_-
# 3       CAMTA1_chr1_6825091_+,CAMTA1_chr1_6785576_+   CAMTA1_chr1_6825091_+
# 4       CAMTA1_chr1_6887653_+,CAMTA1_chr1_6825211_+   CAMTA1_chr1_6887653_+
# ...                                             ...                     ...
# 2750  RPL10_chrX_154400701_+,RPL10_chrX_154399942_+  RPL10_chrX_154400701_+
# 2751  RPL10_chrX_154400701_+,RPL10_chrX_154400627_+  RPL10_chrX_154400701_+
# 2752    USP9Y_chrY_12702009_+,USP9Y_chrY_12664687_+   USP9Y_chrY_12702009_+
# 2753    USP9Y_chrY_12702009_+,USP9Y_chrY_12686607_+   USP9Y_chrY_12702009_+
# 2754    USP9Y_chrY_12709387_+,USP9Y_chrY_12702056_+   USP9Y_chrY_12709387_+
#
#               intron_group_2   grouping_1  grouping_2
# 0         HES4_chr1_999865_-  three_prime  five_prime
# 1        GNB1_chr1_1890819_-  three_prime  five_prime
# 2      FAAP20_chr1_2194687_-  three_prime  five_prime
# 3      CAMTA1_chr1_6785576_+  three_prime  five_prime
# 4      CAMTA1_chr1_6825211_+  three_prime  five_prime
# ...                      ...          ...         ...
# 2750  RPL10_chrX_154399942_+  three_prime  five_prime
# 2751  RPL10_chrX_154400627_+  three_prime  five_prime
# 2752   USP9Y_chrY_12664687_+  three_prime  five_prime
# 2753   USP9Y_chrY_12686607_+  three_prime  five_prime
# 2754   USP9Y_chrY_12702056_+  three_prime  five_prime
#
# [2755 rows x 8 columns]

# %%
introns = temp[~temp.duplicated(subset=temp.columns[:11],keep=False)]

# %%
introns
# Out:
#                               chromosome     start       end strand  \
# HES4_chr1:999614-999691             chr1    999614    999691      -
# HES4_chr1:999788-999865             chr1    999788    999865      -
# AURKAIP1_chr1:1374791-1374996       chr1   1374791   1374996      -
# AURKAIP1_chr1:1374791-1375153       chr1   1374791   1375153      -
# CCNL2_chr1:1390866-1393395          chr1   1390866   1393395      -
# ...                                  ...       ...       ...    ...
# USP9Y_chrY:12690442-12702009        chrY  12690442  12702009      +
# USP9Y_chrY:12699641-12702009        chrY  12699641  12702009      +
# USP9Y_chrY:12702056-12707759        chrY  12702056  12707759      +
# USP9Y_chrY:12702056-12708633        chrY  12702056  12708633      +
# USP9Y_chrY:12708694-12709387        chrY  12708694  12709387      +
#
#                                intron_motif  n_cells    gene_id_start  \
# HES4_chr1:999614-999691                   2      724  ENSG00000188290
# HES4_chr1:999788-999865                   2      279  ENSG00000188290
# AURKAIP1_chr1:1374791-1374996             2      223  ENSG00000175756
# AURKAIP1_chr1:1374791-1375153             2     2599  ENSG00000175756
# CCNL2_chr1:1390866-1393395                2      234  ENSG00000221978
# ...                                     ...      ...              ...
# USP9Y_chrY:12690442-12702009              1      448  ENSG00000114374
# USP9Y_chrY:12699641-12702009              1      274
# USP9Y_chrY:12702056-12707759              1      151  ENSG00000114374
# USP9Y_chrY:12702056-12708633              1      192  ENSG00000114374
# USP9Y_chrY:12708694-12709387              1      243  ENSG00000114374
#
#                                    gene_id_end  n_genes          gene_id  \
# HES4_chr1:999614-999691        ENSG00000188290        1  ENSG00000188290
# HES4_chr1:999788-999865        ENSG00000188290        1  ENSG00000188290
# AURKAIP1_chr1:1374791-1374996  ENSG00000175756        1  ENSG00000175756
# AURKAIP1_chr1:1374791-1375153  ENSG00000175756        1  ENSG00000175756
# CCNL2_chr1:1390866-1393395     ENSG00000221978        1  ENSG00000221978
# ...                                        ...      ...              ...
# USP9Y_chrY:12690442-12702009   ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12699641-12702009   ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12702056-12707759   ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12702056-12708633   ENSG00000114374        1  ENSG00000114374
# USP9Y_chrY:12708694-12709387   ENSG00000114374        1  ENSG00000114374
#
#                               gene_name             intron_group  \
# HES4_chr1:999614-999691            HES4       HES4_chr1_999614_-
# HES4_chr1:999788-999865            HES4       HES4_chr1_999865_-
# AURKAIP1_chr1:1374791-1374996  AURKAIP1  AURKAIP1_chr1_1374791_-
# AURKAIP1_chr1:1374791-1375153  AURKAIP1  AURKAIP1_chr1_1374791_-
# CCNL2_chr1:1390866-1393395        CCNL2     CCNL2_chr1_1393395_-
# ...                                 ...                      ...
# USP9Y_chrY:12690442-12702009      USP9Y    USP9Y_chrY_12702009_+
# USP9Y_chrY:12699641-12702009      USP9Y    USP9Y_chrY_12702009_+
# USP9Y_chrY:12702056-12707759      USP9Y    USP9Y_chrY_12702056_+
# USP9Y_chrY:12702056-12708633      USP9Y    USP9Y_chrY_12702056_+
# USP9Y_chrY:12708694-12709387      USP9Y    USP9Y_chrY_12709387_+
#
#                                intron_group_size  n_genes_per_intron_group  \
# HES4_chr1:999614-999691                        2                         1
# HES4_chr1:999788-999865                        2                         1
# AURKAIP1_chr1:1374791-1374996                  2                         1
# AURKAIP1_chr1:1374791-1375153                  2                         1
# CCNL2_chr1:1390866-1393395                     2                         1
# ...                                          ...                       ...
# USP9Y_chrY:12690442-12702009                   4                         1
# USP9Y_chrY:12699641-12702009                   4                         1
# USP9Y_chrY:12702056-12707759                   3                         1
# USP9Y_chrY:12702056-12708633                   3                         1
# USP9Y_chrY:12708694-12709387                   2                         1
#
#                                   grouping
# HES4_chr1:999614-999691        three_prime
# HES4_chr1:999788-999865         five_prime
# AURKAIP1_chr1:1374791-1374996  three_prime
# AURKAIP1_chr1:1374791-1375153  three_prime
# CCNL2_chr1:1390866-1393395      five_prime
# ...                                    ...
# USP9Y_chrY:12690442-12702009   three_prime
# USP9Y_chrY:12699641-12702009   three_prime
# USP9Y_chrY:12702056-12707759    five_prime
# USP9Y_chrY:12702056-12708633    five_prime
# USP9Y_chrY:12708694-12709387   three_prime
#
# [9297 rows x 15 columns]

# %%
dups_intron_group
# Out:
#      chromosome      start        end  \
# 0          chr1     999614     999865
# 1          chr1    1825500    1890819
# 2          chr1    2193911    2194687
# 3          chr1    6785576    6825091
# 4          chr1    6825211    6887653
# ...         ...        ...        ...
# 2750       chrX  154399942  154400701
# 2751       chrX  154400627  154400701
# 2752       chrY   12664687   12702009
# 2753       chrY   12686607   12702009
# 2754       chrY   12702056   12709387
#
#                                        intron_group          intron_group_1  \
# 0             HES4_chr1_999614_-,HES4_chr1_999865_-      HES4_chr1_999614_-
# 1           GNB1_chr1_1825500_-,GNB1_chr1_1890819_-     GNB1_chr1_1825500_-
# 2       FAAP20_chr1_2193911_-,FAAP20_chr1_2194687_-   FAAP20_chr1_2193911_-
# 3       CAMTA1_chr1_6825091_+,CAMTA1_chr1_6785576_+   CAMTA1_chr1_6825091_+
# 4       CAMTA1_chr1_6887653_+,CAMTA1_chr1_6825211_+   CAMTA1_chr1_6887653_+
# ...                                             ...                     ...
# 2750  RPL10_chrX_154400701_+,RPL10_chrX_154399942_+  RPL10_chrX_154400701_+
# 2751  RPL10_chrX_154400701_+,RPL10_chrX_154400627_+  RPL10_chrX_154400701_+
# 2752    USP9Y_chrY_12702009_+,USP9Y_chrY_12664687_+   USP9Y_chrY_12702009_+
# 2753    USP9Y_chrY_12702009_+,USP9Y_chrY_12686607_+   USP9Y_chrY_12702009_+
# 2754    USP9Y_chrY_12709387_+,USP9Y_chrY_12702056_+   USP9Y_chrY_12709387_+
#
#               intron_group_2   grouping_1  grouping_2
# 0         HES4_chr1_999865_-  three_prime  five_prime
# 1        GNB1_chr1_1890819_-  three_prime  five_prime
# 2      FAAP20_chr1_2194687_-  three_prime  five_prime
# 3      CAMTA1_chr1_6785576_+  three_prime  five_prime
# 4      CAMTA1_chr1_6825211_+  three_prime  five_prime
# ...                      ...          ...         ...
# 2750  RPL10_chrX_154399942_+  three_prime  five_prime
# 2751  RPL10_chrX_154400627_+  three_prime  five_prime
# 2752   USP9Y_chrY_12664687_+  three_prime  five_prime
# 2753   USP9Y_chrY_12686607_+  three_prime  five_prime
# 2754   USP9Y_chrY_12702056_+  three_prime  five_prime
#
# [2755 rows x 8 columns]

# %%
intron_group_1
# Out:
# 'MIER1_chr1_66940027_+'

# %%
intron_group_2
# Out:
# 'MIER1_chr1_66926243_+'

# %%
dups_intron_group
# Out:
#      chromosome      start        end  \
# 0          chr1     999614     999865
# 1          chr1    1825500    1890819
# 2          chr1    2193911    2194687
# 3          chr1    6785576    6825091
# 4          chr1    6825211    6887653
# ...         ...        ...        ...
# 2750       chrX  154399942  154400701
# 2751       chrX  154400627  154400701
# 2752       chrY   12664687   12702009
# 2753       chrY   12686607   12702009
# 2754       chrY   12702056   12709387
#
#                                        intron_group          intron_group_1  \
# 0             HES4_chr1_999614_-,HES4_chr1_999865_-      HES4_chr1_999614_-
# 1           GNB1_chr1_1825500_-,GNB1_chr1_1890819_-     GNB1_chr1_1825500_-
# 2       FAAP20_chr1_2193911_-,FAAP20_chr1_2194687_-   FAAP20_chr1_2193911_-
# 3       CAMTA1_chr1_6825091_+,CAMTA1_chr1_6785576_+   CAMTA1_chr1_6825091_+
# 4       CAMTA1_chr1_6887653_+,CAMTA1_chr1_6825211_+   CAMTA1_chr1_6887653_+
# ...                                             ...                     ...
# 2750  RPL10_chrX_154400701_+,RPL10_chrX_154399942_+  RPL10_chrX_154400701_+
# 2751  RPL10_chrX_154400701_+,RPL10_chrX_154400627_+  RPL10_chrX_154400701_+
# 2752    USP9Y_chrY_12702009_+,USP9Y_chrY_12664687_+   USP9Y_chrY_12702009_+
# 2753    USP9Y_chrY_12702009_+,USP9Y_chrY_12686607_+   USP9Y_chrY_12702009_+
# 2754    USP9Y_chrY_12709387_+,USP9Y_chrY_12702056_+   USP9Y_chrY_12709387_+
#
#               intron_group_2   grouping_1  grouping_2
# 0         HES4_chr1_999865_-  three_prime  five_prime
# 1        GNB1_chr1_1890819_-  three_prime  five_prime
# 2      FAAP20_chr1_2194687_-  three_prime  five_prime
# 3      CAMTA1_chr1_6785576_+  three_prime  five_prime
# 4      CAMTA1_chr1_6825211_+  three_prime  five_prime
# ...                      ...          ...         ...
# 2750  RPL10_chrX_154399942_+  three_prime  five_prime
# 2751  RPL10_chrX_154400627_+  three_prime  five_prime
# 2752   USP9Y_chrY_12664687_+  three_prime  five_prime
# 2753   USP9Y_chrY_12686607_+  three_prime  five_prime
# 2754   USP9Y_chrY_12702056_+  three_prime  five_prime
#
# [2755 rows x 8 columns]

# %%
for index, row in dups_intron_group.head(12).iterrows():
    chromosome = row['chromosome']
    start = row['start']
    end = row['end']
    
    intron_group_1 = row['intron_group_1']
    grouping_1 = row['grouping_1']
    intron_group_2 = row['intron_group_2']
    grouping_2 = row['grouping_2']
    
    intron_group_3prime = row['intron_group_1'] if row['grouping_1'] == 'three_prime' else row['intron_group_2']
    intron_group_5prime = row['intron_group_2'] if row['grouping_2'] == 'five_prime' else row['intron_group_1']
    
    
    
    
    introns_3prime = introns[(introns['intron_group'] == intron_group_3prime) & (introns['grouping'] == 'three_prime')]
    
    coordinates_3prime = introns_3prime['end']
    n_three_prime = = len(coordinates_3prime)


    introns_5prime = introns[(introns['intron_group'] == intron_group_5prime) & (introns['grouping'] == 'five_prime')]
    
    coordinates_5prime = introns_5prime['start']
    n_five_prime = len(coordinates_5prime)

    
    if coordinates_3prime.empty | coordinates_5prime.empty:
        pass
    else:
        n_cells = 
        intron_group_size = 
        
        new_frame = {'chromosome':}
        
    
    

    #print(introns_3prime.shape, " ", introns_5prime.shape)
    #if intron_1.grouping != intron_2.grouping

# %%
introns_3prime
# Out:
#                              chromosome     start       end strand  \
# NBPF1_chr1:16594662-16594930       chr1  16594662  16594930      -
#
#                               intron_motif  n_cells    gene_id_start  \
# NBPF1_chr1:16594662-16594930             2      228  ENSG00000219481
#
#                                   gene_id_end  n_genes          gene_id  \
# NBPF1_chr1:16594662-16594930  ENSG00000219481        1  ENSG00000219481
#
#                              gene_name           intron_group  \
# NBPF1_chr1:16594662-16594930     NBPF1  NBPF1_chr1_16594662_-
#
#                               intron_group_size  n_genes_per_intron_group  \
# NBPF1_chr1:16594662-16594930                  2                         1
#
#                                  grouping
# NBPF1_chr1:16594662-16594930  three_prime

# %%
coordinates_3prime
# Out:
# NBPF1_chr1:16594662-16594930    16594930
# Name: end, dtype: int64

# %%
coordinates_5prime
# Out:
# NBPF1_chr1:16595010-16608507    16595010
# NBPF1_chr1:16595014-16608507    16595014
# NBPF1_chr1:16597681-16608507    16597681
# Name: start, dtype: int64

# %%
dups[dups.gene_name == 'NBPF1']
# Out:
#                              chromosome     start       end strand  \
# NBPF1_chr1:16594662-16608507       chr1  16594662  16608507      -
# NBPF1_chr1:16594662-16608507       chr1  16594662  16608507      -
#
#                               intron_motif  n_cells    gene_id_start  \
# NBPF1_chr1:16594662-16608507             2      164  ENSG00000219481
# NBPF1_chr1:16594662-16608507             2      164  ENSG00000219481
#
#                                   gene_id_end  n_genes          gene_id  \
# NBPF1_chr1:16594662-16608507  ENSG00000219481        1  ENSG00000219481
# NBPF1_chr1:16594662-16608507  ENSG00000219481        1  ENSG00000219481
#
#                              gene_name           intron_group  \
# NBPF1_chr1:16594662-16608507     NBPF1  NBPF1_chr1_16594662_-
# NBPF1_chr1:16594662-16608507     NBPF1  NBPF1_chr1_16608507_-
#
#                               intron_group_size  n_genes_per_intron_group  \
# NBPF1_chr1:16594662-16608507                  2                         1
# NBPF1_chr1:16594662-16608507                  4                         1
#
#                                  grouping
# NBPF1_chr1:16594662-16608507  three_prime
# NBPF1_chr1:16594662-16608507   five_prime

# %%
introns_3prime
# Out:
#                              chromosome     start       end strand  \
# NBPF1_chr1:16594662-16594930       chr1  16594662  16594930      -
#
#                               intron_motif  n_cells    gene_id_start  \
# NBPF1_chr1:16594662-16594930             2      228  ENSG00000219481
#
#                                   gene_id_end  n_genes          gene_id  \
# NBPF1_chr1:16594662-16594930  ENSG00000219481        1  ENSG00000219481
#
#                              gene_name           intron_group  \
# NBPF1_chr1:16594662-16594930     NBPF1  NBPF1_chr1_16594662_-
#
#                               intron_group_size  n_genes_per_intron_group  \
# NBPF1_chr1:16594662-16594930                  2                         1
#
#                                  grouping
# NBPF1_chr1:16594662-16594930  three_prime

# %%
introns_5prime
# Out:
#                              chromosome     start       end strand  \
# NBPF1_chr1:16595010-16608507       chr1  16595010  16608507      -
# NBPF1_chr1:16595014-16608507       chr1  16595014  16608507      -
# NBPF1_chr1:16597681-16608507       chr1  16597681  16608507      -
#
#                               intron_motif  n_cells    gene_id_start  \
# NBPF1_chr1:16595010-16608507             2      148  ENSG00000219481
# NBPF1_chr1:16595014-16608507             2      874  ENSG00000219481
# NBPF1_chr1:16597681-16608507             2      121
#
#                                   gene_id_end  n_genes          gene_id  \
# NBPF1_chr1:16595010-16608507  ENSG00000219481        1  ENSG00000219481
# NBPF1_chr1:16595014-16608507  ENSG00000219481        1  ENSG00000219481
# NBPF1_chr1:16597681-16608507  ENSG00000219481        1  ENSG00000219481
#
#                              gene_name           intron_group  \
# NBPF1_chr1:16595010-16608507     NBPF1  NBPF1_chr1_16608507_-
# NBPF1_chr1:16595014-16608507     NBPF1  NBPF1_chr1_16608507_-
# NBPF1_chr1:16597681-16608507     NBPF1  NBPF1_chr1_16608507_-
#
#                               intron_group_size  n_genes_per_intron_group  \
# NBPF1_chr1:16595010-16608507                  4                         1
# NBPF1_chr1:16595014-16608507                  4                         1
# NBPF1_chr1:16597681-16608507                  4                         1
#
#                                 grouping
# NBPF1_chr1:16595010-16608507  five_prime
# NBPF1_chr1:16595014-16608507  five_prime
# NBPF1_chr1:16597681-16608507  five_prime

# %%
var_concat = pd.concat([adata_spl_3p.var, adata_spl_5p.var])
keep_5p = var_concat[~var_concat.index.duplicated()].query('grouping == "five_prime"').index.values

# %%
adata_spl = anndata.concat(
    [adata_spl_3p, adata_spl_5p[:, keep_5p]],
    axis=1,
    merge="same",
)
adata_spl
# Out:
# AnnData object with n_obs × n_vars = 74327 × 12052
#     obs: 'n_counts', 'batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_mito', '_scvi_batch', '_scvi_labels', 'leiden', 'scANVI_simple', 'tech', 'C_scANVI', 'C_scANVI_simple'
#     var: 'chromosome', 'start', 'end', 'strand', 'intron_motif', 'n_cells', 'gene_id_start', 'gene_id_end', 'n_genes', 'gene_id', 'gene_name', 'intron_group', 'intron_group_size', 'n_genes_per_intron_group', 'grouping'
#     obsm: 'X_umap'

# %%
adata_spl.var.grouping.value_counts()
# Out:
# three_prime    7623
# five_prime     4429
# Name: grouping, dtype: int64

# %%
adata_spl.var[adata_spl.var.gene_name == 'HES4']
# Out:
#                         chromosome   start     end strand  intron_motif  \
# HES4_chr1:999614-999691       chr1  999614  999691      -             2
# HES4_chr1:999614-999865       chr1  999614  999865      -             2
# HES4_chr1:999788-999865       chr1  999788  999865      -             2
#
#                          n_cells    gene_id_start      gene_id_end  n_genes  \
# HES4_chr1:999614-999691      724  ENSG00000188290  ENSG00000188290        1
# HES4_chr1:999614-999865      217  ENSG00000188290  ENSG00000188290        1
# HES4_chr1:999788-999865      279  ENSG00000188290  ENSG00000188290        1
#
#                                  gene_id gene_name        intron_group  \
# HES4_chr1:999614-999691  ENSG00000188290      HES4  HES4_chr1_999614_-
# HES4_chr1:999614-999865  ENSG00000188290      HES4  HES4_chr1_999614_-
# HES4_chr1:999788-999865  ENSG00000188290      HES4  HES4_chr1_999865_-
#
#                          intron_group_size  n_genes_per_intron_group  \
# HES4_chr1:999614-999691                  2                         1
# HES4_chr1:999614-999865                  2                         1
# HES4_chr1:999788-999865                  2                         1
#
#                             grouping
# HES4_chr1:999614-999691  three_prime
# HES4_chr1:999614-999865  three_prime
# HES4_chr1:999788-999865   five_prime

# %%
adata_spl.write_h5ad(output_dir +'adata_spl.h5ad')

# %%
# !conda list
# Out:
# # packages in environment at /c4/home/derek/miniconda3/envs/squint_2:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                  2_kmp_llvm    conda-forge
# anndata                   0.8.0                    pypi_0    pypi
# anyio                     3.5.0           py310h06a4308_0
# appdirs                   1.4.4                    pypi_0    pypi
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0          py310h7f8727e_0
# arpack                    3.7.0                hdefa2d7_2    conda-forge
# asttokens                 2.0.5              pyhd3eb1b0_0
# attrs                     22.1.0          py310h06a4308_0
# babel                     2.11.0          py310h06a4308_0
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.11.1          py310h06a4308_0
# bleach                    4.1.0              pyhd3eb1b0_0
# brotlipy                  0.7.0           py310h5764c6d_1005    conda-forge
# bzip2                     1.0.8                h7b6447c_0
# c-ares                    1.18.1               h7f98852_0    conda-forge
# ca-certificates           2022.12.7            ha878542_0    conda-forge
# certifi                   2022.12.7          pyhd8ed1ab_0    conda-forge
# cffi                      1.15.1          py310h255011f_3    conda-forge
# charset-normalizer        2.1.1              pyhd8ed1ab_0    conda-forge
# colorama                  0.4.6              pyhd8ed1ab_0    conda-forge
# comm                      0.1.2           py310h06a4308_0
# conda                     22.11.1         py310hff52083_1    conda-forge
# conda-package-handling    2.0.2              pyh38be061_0    conda-forge
# conda-package-streaming   0.7.0              pyhd8ed1ab_1    conda-forge
# configargparse            1.5.3                    pypi_0    pypi
# connection-pool           0.0.3                    pypi_0    pypi
# contourpy                 1.0.7                    pypi_0    pypi
# cryptography              39.0.0          py310h65dfdc0_0    conda-forge
# cycler                    0.11.0                   pypi_0    pypi
# datrie                    0.8.2                    pypi_0    pypi
# debugpy                   1.5.1           py310h295c915_0
# decorator                 5.1.1              pyhd3eb1b0_0
# defusedxml                0.7.1              pyhd3eb1b0_0
# docutils                  0.19                     pypi_0    pypi
# dpath                     2.1.4                    pypi_0    pypi
# entrypoints               0.4             py310h06a4308_0
# executing                 0.8.3              pyhd3eb1b0_0
# flit-core                 3.6.0              pyhd3eb1b0_0
# fmt                       9.1.0                h924138e_0    conda-forge
# fonttools                 4.38.0                   pypi_0    pypi
# gitdb                     4.0.10                   pypi_0    pypi
# gitpython                 3.1.30                   pypi_0    pypi
# glpk                      5.0                  h445213a_0    conda-forge
# gmp                       6.2.1                h58526e2_0    conda-forge
# h5py                      3.7.0                    pypi_0    pypi
# icu                       70.1                 h27087fc_0    conda-forge
# idna                      3.4                pyhd8ed1ab_0    conda-forge
# igraph                    0.10.3               hb9ddf80_0    conda-forge
# ipykernel                 6.19.2          py310h2f386ee_0
# ipython                   8.7.0           py310h06a4308_0
# ipython_genutils          0.2.0              pyhd3eb1b0_1
# jedi                      0.18.1          py310h06a4308_1
# jinja2                    3.1.2           py310h06a4308_0
# joblib                    1.2.0                    pypi_0    pypi
# json5                     0.9.6              pyhd3eb1b0_0
# jsonschema                4.16.0          py310h06a4308_0
# jupyter_client            7.4.8           py310h06a4308_0
# jupyter_core              5.1.1           py310h06a4308_0
# jupyter_server            1.23.4          py310h06a4308_0
# jupyterlab                3.5.2           py310h06a4308_0
# jupyterlab_pygments       0.1.2                      py_0
# jupyterlab_server         2.16.5          py310h06a4308_0
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# kiwisolver                1.4.4                    pypi_0    pypi
# krb5                      1.19.3               h3790be6_0    conda-forge
# ld_impl_linux-64          2.38                 h1181459_1
# leidenalg                 0.9.1           py310heca2aa9_0    conda-forge
# libarchive                3.5.2                hccf745f_1    conda-forge
# libblas                   3.9.0           16_linux64_openblas    conda-forge
# libcblas                  3.9.0           16_linux64_openblas    conda-forge
# libcurl                   7.86.0               h91b91d3_0
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 h516909a_1    conda-forge
# libffi                    3.4.2                h6a678d5_6
# libgcc-ng                 12.2.0              h65d4601_19    conda-forge
# libgfortran-ng            12.2.0              h69a702a_19    conda-forge
# libgfortran5              12.2.0              h337968e_19    conda-forge
# libhwloc                  2.8.0                h32351e8_1    conda-forge
# libiconv                  1.17                 h166bdaf_0    conda-forge
# liblapack                 3.9.0           16_linux64_openblas    conda-forge
# libmamba                  1.1.0                h2c5f835_2    conda-forge
# libmambapy                1.1.0           py310h5976e0f_2    conda-forge
# libnghttp2                1.46.0               hce63b2e_0
# libopenblas               0.3.21          pthreads_h78a6416_3    conda-forge
# libsodium                 1.0.18               h7b6447c_0
# libsolv                   0.7.22               he621ea3_0
# libssh2                   1.10.0               ha56f1ee_2    conda-forge
# libstdcxx-ng              12.2.0              h46fd767_19    conda-forge
# libuuid                   1.41.5               h5eee18b_0
# libxml2                   2.10.3               h7463322_0    conda-forge
# libxslt                   1.1.37               h873f0b0_0    conda-forge
# libzlib                   1.2.13               h166bdaf_4    conda-forge
# llvm-openmp               14.0.6               h9e868ea_0
# llvmlite                  0.39.1                   pypi_0    pypi
# lxml                      4.9.2           py310hbdc0903_0    conda-forge
# lz4-c                     1.9.3                h9c3ff4c_1    conda-forge
# lzo                       2.10              h516909a_1000    conda-forge
# mamba                     1.1.0           py310hf87f941_2    conda-forge
# markupsafe                2.1.1           py310h7f8727e_0
# matplotlib                3.6.3                    pypi_0    pypi
# matplotlib-inline         0.1.6           py310h06a4308_0
# metis                     5.1.0             h58526e2_1006    conda-forge
# mistune                   0.8.4           py310h7f8727e_1000
# mpfr                      4.1.0                h9202a9a_1    conda-forge
# natsort                   8.2.0                    pypi_0    pypi
# nbclassic                 0.4.8           py310h06a4308_0
# nbclient                  0.5.13          py310h06a4308_0
# nbconvert                 6.5.4           py310h06a4308_0
# nbformat                  5.7.0           py310h06a4308_0
# ncurses                   6.3                  h5eee18b_3
# nest-asyncio              1.5.6           py310h06a4308_0
# networkx                  3.0                      pypi_0    pypi
# notebook                  6.5.2           py310h06a4308_0
# notebook-shim             0.2.2           py310h06a4308_0
# numba                     0.56.4                   pypi_0    pypi
# numpy                     1.23.5                   pypi_0    pypi
# nvidia-cublas-cu11        11.10.3.66               pypi_0    pypi
# nvidia-cuda-nvrtc-cu11    11.7.99                  pypi_0    pypi
# nvidia-cuda-runtime-cu11  11.7.99                  pypi_0    pypi
# nvidia-cudnn-cu11         8.5.0.96                 pypi_0    pypi
# openssl                   1.1.1s               h0b41bf4_1    conda-forge
# opt-einsum                3.3.0                    pypi_0    pypi
# packaging                 22.0            py310h06a4308_0
# pandas                    1.5.2                    pypi_0    pypi
# pandocfilters             1.5.0              pyhd3eb1b0_0
# parso                     0.8.3              pyhd3eb1b0_0
# patsy                     0.5.3                    pypi_0    pypi
# pcre2                     10.37                h032f7d1_0    conda-forge
# pexpect                   4.8.0              pyhd3eb1b0_3
# pickleshare               0.7.5           pyhd3eb1b0_1003
# pillow                    9.4.0                    pypi_0    pypi
# pip                       22.3.1          py310h06a4308_0
# plac                      1.3.5                    pypi_0    pypi
# platformdirs              2.5.2           py310h06a4308_0
# pluggy                    1.0.0              pyhd8ed1ab_5    conda-forge
# prometheus_client         0.14.1          py310h06a4308_0
# prompt-toolkit            3.0.36          py310h06a4308_0
# psutil                    5.9.0           py310h5eee18b_0
# ptyprocess                0.7.0              pyhd3eb1b0_2
# pulp                      2.7.0                    pypi_0    pypi
# pure_eval                 0.2.2              pyhd3eb1b0_0
# pybind11-abi              4                    hd8ed1ab_3    conda-forge
# pycosat                   0.6.4           py310h5764c6d_1    conda-forge
# pycparser                 2.21               pyhd8ed1ab_0    conda-forge
# pygments                  2.11.2             pyhd3eb1b0_0
# pynndescent               0.5.8                    pypi_0    pypi
# pyopenssl                 23.0.0             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.0.9                    pypi_0    pypi
# pyro-api                  0.1.2                    pypi_0    pypi
# pyro-ppl                  1.8.4                    pypi_0    pypi
# pyrsistent                0.18.0          py310h7f8727e_0
# pysocks                   1.7.1              pyha2e5f31_6    conda-forge
# python                    3.10.8               h7a1cb2a_1
# python-dateutil           2.8.2              pyhd3eb1b0_0
# python-fastjsonschema     2.16.2          py310h06a4308_0
# python-igraph             0.10.3          py310hc734324_0    conda-forge
# python_abi                3.10                    2_cp310    conda-forge
# pytz                      2022.7          py310h06a4308_0
# pyyaml                    6.0                      pypi_0    pypi
# pyzmq                     23.2.0          py310h6a678d5_0
# readline                  8.2                  h5eee18b_0
# reproc                    14.2.4               h0b41bf4_0    conda-forge
# reproc-cpp                14.2.4               hcb278e6_0    conda-forge
# requests                  2.28.1             pyhd8ed1ab_1    conda-forge
# reretry                   0.11.8                   pypi_0    pypi
# ruamel.yaml               0.17.21         py310h5764c6d_2    conda-forge
# ruamel.yaml.clib          0.2.7           py310h1fa729e_1    conda-forge
# scanpy                    1.9.1                    pypi_0    pypi
# scikit-learn              1.2.0                    pypi_0    pypi
# scipy                     1.10.0                   pypi_0    pypi
# scquint                   0.3.3                     dev_0    <develop>
# seaborn                   0.12.2                   pypi_0    pypi
# send2trash                1.8.0              pyhd3eb1b0_1
# session-info              1.0.0                    pypi_0    pypi
# setuptools                65.6.3          py310h06a4308_0
# six                       1.16.0             pyhd3eb1b0_1
# smart-open                6.3.0                    pypi_0    pypi
# smmap                     5.0.0                    pypi_0    pypi
# snakemake                 7.19.1                   pypi_0    pypi
# sniffio                   1.2.0           py310h06a4308_1
# soupsieve                 2.3.2.post1     py310h06a4308_0
# sqlite                    3.40.1               h5082296_0
# stack_data                0.2.0              pyhd3eb1b0_0
# statsmodels               0.13.5                   pypi_0    pypi
# stdlib-list               0.8.0                    pypi_0    pypi
# stopit                    1.1.2                    pypi_0    pypi
# suitesparse               5.10.1               h9e50725_1    conda-forge
# tabulate                  0.9.0                    pypi_0    pypi
# tbb                       2021.7.0             h924138e_1    conda-forge
# terminado                 0.17.1          py310h06a4308_0
# texttable                 1.6.7              pyhd8ed1ab_0    conda-forge
# threadpoolctl             3.1.0                    pypi_0    pypi
# throttler                 1.2.2                    pypi_0    pypi
# tinycss2                  1.2.1           py310h06a4308_0
# tk                        8.6.12               h1ccaba5_0
# tomli                     2.0.1           py310h06a4308_0
# toolz                     0.12.0             pyhd8ed1ab_0    conda-forge
# toposort                  1.9                      pypi_0    pypi
# torch                     1.13.1                   pypi_0    pypi
# tornado                   6.2             py310h5eee18b_0
# tqdm                      4.64.1             pyhd8ed1ab_0    conda-forge
# traitlets                 5.7.1           py310h06a4308_0
# typing-extensions         4.4.0           py310h06a4308_0
# typing_extensions         4.4.0           py310h06a4308_0
# tzdata                    2022g                h04d1e81_0
# umap-learn                0.5.3                    pypi_0    pypi
# urllib3                   1.26.14            pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.5              pyhd3eb1b0_0
# webencodings              0.5.1           py310h06a4308_1
# websocket-client          0.58.0          py310h06a4308_4
# wheel                     0.37.1             pyhd3eb1b0_0
# wrapt                     1.14.1                   pypi_0    pypi
# xz                        5.2.8                h5eee18b_0
# yaml-cpp                  0.7.0                h27087fc_2    conda-forge
# yte                       1.5.1                    pypi_0    pypi
# zeromq                    4.3.4                h2531618_0
# zlib                      1.2.13               h166bdaf_4    conda-forge
# zstandard                 0.19.0          py310hdeb6495_1    conda-forge
# zstd                      1.5.2                ha4553b6_0
